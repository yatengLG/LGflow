# %% [markdown]
# # 本文件展示了LGflow与torch在链式求导以及梯度更新时的对比

# %%
from torch import nn as t_nn
from torch import optim as t_optim
import torch

# %%
from LG_flow import nn as l_nn
from LG_flow import optim as l_optim
import LG_flow

# %% [markdown]
# # 一. 创建模型

# %% [markdown]
# ## 1.1 创建torch模型
#     创建一个两层全连接的torch模型。

# %%
class TNet(t_nn.Module):
    def __init__(self):
        super().__init__()

        self.fc1 = t_nn.Linear(5, 4)
        self.fc2 = t_nn.Linear(4, 3)

    def forward(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        return x

t_net = TNet()

# %%
t_net
# Out:
# TNet(
#   (fc1): Linear(in_features=5, out_features=4, bias=True)
#   (fc2): Linear(in_features=4, out_features=3, bias=True)
# )

# %% [markdown]
# ## 1.2 创建LGflow模型
#     通过LGflow，创建一个结构相同的模型。

# %%
class LNet(l_nn.Module):
    def __init__(self):
        super().__init__()

        self.fc1 = l_nn.Linear(5, 4)
        self.fc2 = l_nn.Linear(4, 3)

    def forward(self, x):
        x = self.fc1.forward(x)
        x = self.fc2.forward(x)
        return x

l_net = LNet()

# %%
print(l_net)
# Out:
# <__main__.LNet object at 0x7b4444a2a250>

# %% [markdown]
# ## 1.3 使LGflow模型的参数与torch模型参数相同

# %%
l_net.fc1.weights = l_nn.Parameter(t_net.fc1.weight.data.numpy())
l_net.fc1.bias = l_nn.Parameter(t_net.fc1.bias.data.numpy())
l_net.fc2.weights = l_nn.Parameter(t_net.fc2.weight.data.numpy())
l_net.fc2.bias = l_nn.Parameter(t_net.fc2.bias.data.numpy())

# %% [markdown]
# # 二. 创建输入

# %%
t_x = torch.randn(2, 5)    # input for torch
t_t = torch.tensor([[1, 0, 0], [0, 1, 0]], dtype=torch.float32)    # target for torch

# %%
t_x
# Out:
# tensor([[-0.2327,  0.7217, -1.4293,  0.1198, -0.5560],
#         [ 0.0727, -0.5051,  0.0142,  0.4959,  1.1959]])

# %%
l_x = LG_flow.Tensor(t_x.data.numpy())    # input for LGflow
l_t = LG_flow.Tensor([[1, 0, 0], [0, 1, 0]])    # target for LGflow

# %%
print(l_x)
# Out:
# (Tensor shape=(2, 5) dtype=float32 required_grad=False grad_fn=None
# [[-0.23269808  0.7217442  -1.4292643   0.11977072 -0.5560263 ]
#  [ 0.07265634 -0.50506955  0.0142369   0.4958788   1.1958818 ]]
# )

# %% [markdown]
# # 三. 创建损失函数

# %%
t_loss_fn = t_nn.CrossEntropyLoss(reduction='sum')

# %%
l_loss_fn = l_nn.CrossEntropyLoss(reduction='sum')

# %% [markdown]
# # 四. 创建优化器

# %%
t_optimizer = t_optim.SGD(t_net.parameters(), lr=0.01)

# %%
l_optimizer = l_optim.SGD(l_net.parameters(), lr=0.01)

# %% [markdown]
# # 五. 反向传播更新模型参数
#
#     以epoch次反向更新为例，展示了LGflow与torch在

# %%
epochs = 20

# %%
for epoch in range(epochs):
    print('-'*50 + f'epoch: {epoch}' + '-'*50)
    
    # torch forward
    t_y = t_net.forward(t_x)
    print('t_y: ', t_y)

    # LGflow forward
    l_y = l_net.forward(l_x)
    print('l_y: ', l_y)
    print()
    
    # torch loss
    t_loss = t_loss_fn(t_y, t_t)
    print('t_loss: ', t_loss)

    # LGflow loss
    l_loss = l_loss_fn.forward(l_y, l_t)
    print('l_loss: ', l_loss)
    print()

    # torch backward
    t_optimizer.zero_grad()
    t_loss.backward()

    # LGflow backward
    l_optimizer.zero_grad()
    l_loss.backward()

    # check parameters
    ## torch parameters
    for param in t_net.parameters():
        print('torch model paramenters 0 value: ')
        print(param)
        print('torch model paramenters 0 grad: ')
        print(param.grad)
        break
        
    print()
    
    ## LGflow parameters
    for name, param in l_net.parameters().items():
        print('LGflow model paramenters 0 value: ')
        print(param)
        print('LGflow model paramenters 0 grad: ')
        print(param.grad)
        break
# Out:
# --------------------------------------------------epoch: 0--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c25e0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6c2a60>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 1--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2be0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5340>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 2--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c28e0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6c27f0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 3--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2e50>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5070>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 4--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2460>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d53d0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 5--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2fa0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d52b0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 6--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2910>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5400>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 7--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2fd0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5040>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 8--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2910>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d53d0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 9--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2f10>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d53a0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 10--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2730>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5580>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 11--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6d53a0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5460>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 12--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2580>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5640>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 13--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6d5070>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d52b0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 14--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2700>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5700>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 15--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2970>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d57f0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 16--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2580>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d57c0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 17--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2490>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5820>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 18--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c27c0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5850>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 19--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2fa0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d52b0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 20--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c23d0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d57c0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 21--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2d00>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d51f0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 22--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2a00>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5310>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 23--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2970>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5340>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 24--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c25b0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d54c0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 25--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2ac0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5460>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 26--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6c2a90>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6d5400>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
# ...
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6f99d0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 92--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6d7cd0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6f9cd0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 93--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6f9f70>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6f9fd0>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 94--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6d7d00>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6f9400>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 95--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6f9a60>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6f9790>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 96--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6d79a0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6f9670>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 97--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6f9be0>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6f9b20>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 98--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6d7e80>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6f9250>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
# --------------------------------------------------epoch: 99--------------------------------------------------
# t_y:  tensor([[-0.3071, -0.2586,  0.3973],
#         [-0.1089, -0.0570,  0.2766]], grad_fn=<AddmmBackward0>)
# l_y:  (Tensor shape=(2, 3) dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.ADD_WITH_TENSOR object at 0x7b443b6f9310>
# [[-0.30705327 -0.25855625  0.39733762]
#  [-0.10889795 -0.0570376   0.27660614]]
# )
#
# t_loss:  tensor(2.6118, grad_fn=<NegBackward0>)
# l_loss:  (Tensor shape=() dtype=float32 required_grad=False grad_fn=<LG_flow.Math_op.SUM object at 0x7b443b6f9d60>
# 2.611827850341797
# )
#
# torch model paramenters 0 value:
# Parameter containing:
# tensor([[-0.3690,  0.0201,  0.2429, -0.1889,  0.1252],
#         [ 0.3439, -0.4198, -0.1932,  0.2583, -0.4247],
#         [-0.2193, -0.1931, -0.2698,  0.1519, -0.0936],
#         [ 0.2298,  0.1628,  0.3579,  0.0783,  0.1527]], requires_grad=True)
# torch model paramenters 0 grad:
# tensor([[-0.0081,  0.0649,  0.0118, -0.0717, -0.1648],
#         [-0.0521,  0.1780, -0.2945, -0.0045, -0.1845],
#         [-0.0112, -0.0525, -0.2038,  0.1723,  0.2923],
#         [ 0.0148, -0.0460,  0.0911, -0.0076,  0.0354]])
#
# LGflow model paramenters 0 value:
# (Parameter shape=(4, 5) dtype=float32 required_grad=True grad_fn=None
# [[-0.36895394  0.02011436  0.24290143 -0.18891133  0.12521249]
#  [ 0.3438667  -0.419769   -0.19322689  0.25829878 -0.4246961 ]
#  [-0.21929806 -0.19306941 -0.26978368  0.1519014  -0.09364335]
#  [ 0.22979802  0.16282545  0.35793072  0.07833385  0.15266258]]
# )
# LGflow model paramenters 0 grad:
# [[-0.00809658  0.06492189  0.011756   -0.0717285  -0.16483644]
#  [-0.05208705  0.1779877  -0.29454508 -0.0045194  -0.18451706]
#  [-0.01122676 -0.05250204 -0.20382933  0.17225926  0.29231218]
#  [ 0.01483531 -0.04600805  0.09112915 -0.00764653  0.03542806]]
